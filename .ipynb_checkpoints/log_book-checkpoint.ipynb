# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import dateutil
import seaborn as sns
import numpy as np
plt.style.use('seaborn-deep')
colors = {"A330": "#7D94CA", "A321": '#3F569D', "A320": '#1E3174'}

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
logbook = "log_book.csv"
#"338299H_fltlogbook_20151001_20201103.csv"

columns = ['date','flight_num','city_pair','ac_reg','block_time','off_block','airborne','landing','on_block','takeoff','landing','autoland','commander']
df = pd.read_csv(logbook, encoding="utf-8",skiprows=5)
df.columns = columns
df
# Out:
#             date  flight_num city_pair ac_reg block_time off_block airborne  \
# 0      12/9/2012         297   HKG HAN  B-HTF       1:54      0:36     0:53
# 1      12/9/2012         296   HAN HKG  B-HTF       1:58      3:35     3:50
# 2      13/9/2012         212   HKG HKT  B-HSM       3:17      1:10     1:26
# 3      13/9/2012         213   HKT HKG  B-HSM       3:36      5:21     5:32
# 4      3/10/2012         636   HKG HGH  B-HSK       2:04      8:02     8:16
# ...          ...         ...       ...    ...        ...       ...      ...
# 1953   26/9/2020         887   CTU HKG  B-HLT       2:40      5:43     6:14
# 1954  15/10/2020         725   HKG KUL  B-LBE       3:49      5:01     5:13
# 1955  15/10/2020         734   KUL HKG  B-LBE       3:45      9:46     9:58
# 1956  20/10/2020         299   HKG HAN  B-LAA       1:52      9:22     9:35
# 1957  20/10/2020         294   HAN HKG  B-LAA       1:49     12:05    12:26
#
#       landing on_block  takeoff  landing autoland       commander
# 0        2:25     2:30        0        0        N    NETTLETON AD
# 1        5:27     5:33        0        0        N    NETTLETON AD
# 2        4:24     4:27        0        0        N    NETTLETON AD
# 3        8:51     8:57        0        0        N    NETTLETON AD
# 4       10:01    10:06        0        0        N       GUNTON MS
# ...       ...      ...      ...      ...      ...             ...
# 1953     8:16     8:23        0        0        N     O'CONNOR TE
# 1954     8:44     8:50        0        0        N  NADENBOUSCH WJ
# 1955    13:26    13:31        1        1        N  NADENBOUSCH WJ
# 1956    11:06    11:14        1        1        N       JORDAN CR
# 1957    13:47    13:54        0        0        N       JORDAN CR
#
# [1958 rows x 13 columns]

# %%
nulls = df.isnull()
sns.heatmap(data=nulls, cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
#remove the last 5 rows where I placed totals in EXCEL
# df.drop(df.tail(5).index,inplace=True)
# df

# %%
#change flight number from float to int.
df['flight_num'] = df['flight_num'].astype(int)
df
# Out:
#             date  flight_num city_pair ac_reg block_time off_block airborne  \
# 0      12/9/2012         297   HKG HAN  B-HTF       1:54      0:36     0:53
# 1      12/9/2012         296   HAN HKG  B-HTF       1:58      3:35     3:50
# 2      13/9/2012         212   HKG HKT  B-HSM       3:17      1:10     1:26
# 3      13/9/2012         213   HKT HKG  B-HSM       3:36      5:21     5:32
# 4      3/10/2012         636   HKG HGH  B-HSK       2:04      8:02     8:16
# ...          ...         ...       ...    ...        ...       ...      ...
# 1953   26/9/2020         887   CTU HKG  B-HLT       2:40      5:43     6:14
# 1954  15/10/2020         725   HKG KUL  B-LBE       3:49      5:01     5:13
# 1955  15/10/2020         734   KUL HKG  B-LBE       3:45      9:46     9:58
# 1956  20/10/2020         299   HKG HAN  B-LAA       1:52      9:22     9:35
# 1957  20/10/2020         294   HAN HKG  B-LAA       1:49     12:05    12:26
#
#       landing on_block  takeoff  landing autoland       commander
# 0        2:25     2:30        0        0        N    NETTLETON AD
# 1        5:27     5:33        0        0        N    NETTLETON AD
# 2        4:24     4:27        0        0        N    NETTLETON AD
# 3        8:51     8:57        0        0        N    NETTLETON AD
# 4       10:01    10:06        0        0        N       GUNTON MS
# ...       ...      ...      ...      ...      ...             ...
# 1953     8:16     8:23        0        0        N     O'CONNOR TE
# 1954     8:44     8:50        0        0        N  NADENBOUSCH WJ
# 1955    13:26    13:31        1        1        N  NADENBOUSCH WJ
# 1956    11:06    11:14        1        1        N       JORDAN CR
# 1957    13:47    13:54        0        0        N       JORDAN CR
#
# [1958 rows x 13 columns]

# %%
new = df['city_pair'].str.split(expand = True)

df['origin'] = new[0]
df['destination'] = new[1]

df
# Out:
#             date  flight_num city_pair ac_reg block_time off_block airborne  \
# 0      12/9/2012         297   HKG HAN  B-HTF       1:54      0:36     0:53
# 1      12/9/2012         296   HAN HKG  B-HTF       1:58      3:35     3:50
# 2      13/9/2012         212   HKG HKT  B-HSM       3:17      1:10     1:26
# 3      13/9/2012         213   HKT HKG  B-HSM       3:36      5:21     5:32
# 4      3/10/2012         636   HKG HGH  B-HSK       2:04      8:02     8:16
# ...          ...         ...       ...    ...        ...       ...      ...
# 1953   26/9/2020         887   CTU HKG  B-HLT       2:40      5:43     6:14
# 1954  15/10/2020         725   HKG KUL  B-LBE       3:49      5:01     5:13
# 1955  15/10/2020         734   KUL HKG  B-LBE       3:45      9:46     9:58
# 1956  20/10/2020         299   HKG HAN  B-LAA       1:52      9:22     9:35
# 1957  20/10/2020         294   HAN HKG  B-LAA       1:49     12:05    12:26
#
#       landing on_block  takeoff  landing autoland       commander origin  \
# 0        2:25     2:30        0        0        N    NETTLETON AD    HKG
# 1        5:27     5:33        0        0        N    NETTLETON AD    HAN
# 2        4:24     4:27        0        0        N    NETTLETON AD    HKG
# 3        8:51     8:57        0        0        N    NETTLETON AD    HKT
# 4       10:01    10:06        0        0        N       GUNTON MS    HKG
# ...       ...      ...      ...      ...      ...             ...    ...
# 1953     8:16     8:23        0        0        N     O'CONNOR TE    CTU
# 1954     8:44     8:50        0        0        N  NADENBOUSCH WJ    HKG
# 1955    13:26    13:31        1        1        N  NADENBOUSCH WJ    KUL
# 1956    11:06    11:14        1        1        N       JORDAN CR    HKG
# 1957    13:47    13:54        0        0        N       JORDAN CR    HAN
#
#      destination
# 0            HAN
# 1            HKG
# 2            HKT
# 3            HKG
# 4            HGH
# ...          ...
# 1953         HKG
# 1954         KUL
# 1955         HKG
# 1956         HAN
# 1957         HKG
#
# [1958 rows x 15 columns]

# %%
cols = list(df.columns.values)
cols
# Out:
# ['date',
#  'flight_num',
#  'city_pair',
#  'ac_reg',
#  'block_time',
#  'off_block',
#  'airborne',
#  'landing',
#  'on_block',
#  'takeoff',
#  'landing',
#  'autoland',
#  'commander',
#  'origin',
#  'destination']

# %%
df = df[['date',
 'flight_num',
 'city_pair',
 'origin',
 'destination',
 'ac_reg',
 'block_time',
 'off_block',
 'airborne',
 'landing',
 'on_block',
 'takeoff',
 'landing',
 'autoland',
 'commander']]
df
# Out:
#             date  flight_num city_pair origin destination ac_reg block_time  \
# 0      12/9/2012         297   HKG HAN    HKG         HAN  B-HTF       1:54
# 1      12/9/2012         296   HAN HKG    HAN         HKG  B-HTF       1:58
# 2      13/9/2012         212   HKG HKT    HKG         HKT  B-HSM       3:17
# 3      13/9/2012         213   HKT HKG    HKT         HKG  B-HSM       3:36
# 4      3/10/2012         636   HKG HGH    HKG         HGH  B-HSK       2:04
# ...          ...         ...       ...    ...         ...    ...        ...
# 1953   26/9/2020         887   CTU HKG    CTU         HKG  B-HLT       2:40
# 1954  15/10/2020         725   HKG KUL    HKG         KUL  B-LBE       3:49
# 1955  15/10/2020         734   KUL HKG    KUL         HKG  B-LBE       3:45
# 1956  20/10/2020         299   HKG HAN    HKG         HAN  B-LAA       1:52
# 1957  20/10/2020         294   HAN HKG    HAN         HKG  B-LAA       1:49
#
#      off_block airborne  landing  landing on_block  takeoff  landing  landing  \
# 0         0:36     0:53     2:25        0     2:30        0     2:25        0
# 1         3:35     3:50     5:27        0     5:33        0     5:27        0
# 2         1:10     1:26     4:24        0     4:27        0     4:24        0
# 3         5:21     5:32     8:51        0     8:57        0     8:51        0
# 4         8:02     8:16    10:01        0    10:06        0    10:01        0
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 1953      5:43     6:14     8:16        0     8:23        0     8:16        0
# 1954      5:01     5:13     8:44        0     8:50        0     8:44        0
# 1955      9:46     9:58    13:26        1    13:31        1    13:26        1
# 1956      9:22     9:35    11:06        1    11:14        1    11:06        1
# 1957     12:05    12:26    13:47        0    13:54        0    13:47        0
#
#      autoland       commander
# 0           N    NETTLETON AD
# 1           N    NETTLETON AD
# 2           N    NETTLETON AD
# 3           N    NETTLETON AD
# 4           N       GUNTON MS
# ...       ...             ...
# 1953        N     O'CONNOR TE
# 1954        N  NADENBOUSCH WJ
# 1955        N  NADENBOUSCH WJ
# 1956        N       JORDAN CR
# 1957        N       JORDAN CR
#
# [1958 rows x 17 columns]

# %%
pd.set_option('colwidth', 15)
df
# Out:
#             date  flight_num city_pair origin destination ac_reg block_time  \
# 0      12/9/2012         297   HKG HAN    HKG         HAN  B-HTF       1:54
# 1      12/9/2012         296   HAN HKG    HAN         HKG  B-HTF       1:58
# 2      13/9/2012         212   HKG HKT    HKG         HKT  B-HSM       3:17
# 3      13/9/2012         213   HKT HKG    HKT         HKG  B-HSM       3:36
# 4      3/10/2012         636   HKG HGH    HKG         HGH  B-HSK       2:04
# ...          ...         ...       ...    ...         ...    ...        ...
# 1953   26/9/2020         887   CTU HKG    CTU         HKG  B-HLT       2:40
# 1954  15/10/2020         725   HKG KUL    HKG         KUL  B-LBE       3:49
# 1955  15/10/2020         734   KUL HKG    KUL         HKG  B-LBE       3:45
# 1956  20/10/2020         299   HKG HAN    HKG         HAN  B-LAA       1:52
# 1957  20/10/2020         294   HAN HKG    HAN         HKG  B-LAA       1:49
#
#      off_block airborne  landing  landing on_block  takeoff  landing  landing  \
# 0         0:36     0:53     2:25        0     2:30        0     2:25        0
# 1         3:35     3:50     5:27        0     5:33        0     5:27        0
# 2         1:10     1:26     4:24        0     4:27        0     4:24        0
# 3         5:21     5:32     8:51        0     8:57        0     8:51        0
# 4         8:02     8:16    10:01        0    10:06        0    10:01        0
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 1953      5:43     6:14     8:16        0     8:23        0     8:16        0
# 1954      5:01     5:13     8:44        0     8:50        0     8:44        0
# 1955      9:46     9:58    13:26        1    13:31        1    13:26        1
# 1956      9:22     9:35    11:06        1    11:14        1    11:06        1
# 1957     12:05    12:26    13:47        0    13:54        0    13:47        0
#
#      autoland       commander
# 0           N    NETTLETON AD
# 1           N    NETTLETON AD
# 2           N    NETTLETON AD
# 3           N    NETTLETON AD
# 4           N       GUNTON MS
# ...       ...             ...
# 1953        N     O'CONNOR TE
# 1954        N  NADENBOUSCH WJ
# 1955        N  NADENBOUSCH WJ
# 1956        N       JORDAN CR
# 1957        N       JORDAN CR
#
# [1958 rows x 17 columns]

# %%
#The most flown flight number. 803 Shanghai, 212 Phuket, 782 Gz.
df['flight_num'].value_counts().head(20).plot(kind='bar',color= colors["A320"]);

plt.title("Which route did I fly most?")
plt.savefig('Which route did I fly most.png', bbox_inches='tight')

# %%
ac_type = df[df['ac_reg'].str.contains("B-HS")]

# %%
#added column "ac_type" and assigned value "airbus" to all.

new_df = df.assign(ac_type = "airbus")


new_df
# Out:
#             date  flight_num city_pair origin destination ac_reg block_time  \
# 0      12/9/2012         297   HKG HAN    HKG         HAN  B-HTF       1:54
# 1      12/9/2012         296   HAN HKG    HAN         HKG  B-HTF       1:58
# 2      13/9/2012         212   HKG HKT    HKG         HKT  B-HSM       3:17
# 3      13/9/2012         213   HKT HKG    HKT         HKG  B-HSM       3:36
# 4      3/10/2012         636   HKG HGH    HKG         HGH  B-HSK       2:04
# ...          ...         ...       ...    ...         ...    ...        ...
# 1953   26/9/2020         887   CTU HKG    CTU         HKG  B-HLT       2:40
# 1954  15/10/2020         725   HKG KUL    HKG         KUL  B-LBE       3:49
# 1955  15/10/2020         734   KUL HKG    KUL         HKG  B-LBE       3:45
# 1956  20/10/2020         299   HKG HAN    HKG         HAN  B-LAA       1:52
# 1957  20/10/2020         294   HAN HKG    HAN         HKG  B-LAA       1:49
#
#      off_block airborne  landing  landing on_block  takeoff  landing  landing  \
# 0         0:36     0:53     2:25        0     2:30        0     2:25        0
# 1         3:35     3:50     5:27        0     5:33        0     5:27        0
# 2         1:10     1:26     4:24        0     4:27        0     4:24        0
# 3         5:21     5:32     8:51        0     8:57        0     8:51        0
# 4         8:02     8:16    10:01        0    10:06        0    10:01        0
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 1953      5:43     6:14     8:16        0     8:23        0     8:16        0
# 1954      5:01     5:13     8:44        0     8:50        0     8:44        0
# 1955      9:46     9:58    13:26        1    13:31        1    13:26        1
# 1956      9:22     9:35    11:06        1    11:14        1    11:06        1
# 1957     12:05    12:26    13:47        0    13:54        0    13:47        0
#
#      autoland       commander ac_type
# 0           N    NETTLETON AD  airbus
# 1           N    NETTLETON AD  airbus
# 2           N    NETTLETON AD  airbus
# 3           N    NETTLETON AD  airbus
# 4           N       GUNTON MS  airbus
# ...       ...             ...     ...
# 1953        N     O'CONNOR TE  airbus
# 1954        N  NADENBOUSCH WJ  airbus
# 1955        N  NADENBOUSCH WJ  airbus
# 1956        N       JORDAN CR  airbus
# 1957        N       JORDAN CR  airbus
#
# [1958 rows x 18 columns]

# %%
new_df.loc[new_df['ac_reg'].str.contains("B-HS"),'ac_type'] = 'A320'
new_df.loc[new_df['ac_reg'].str.contains("B-HT"),'ac_type'] = 'A321'
new_df.loc[new_df['ac_reg'].str.contains("B-L"),'ac_type'] = 'A330'
new_df.loc[new_df['ac_reg'].str.contains("B-HL"),'ac_type'] = 'A330'
new_df.loc[new_df['ac_reg'].str.contains("B-HY"),'ac_type'] = 'A330'
#new_df.loc[new_df['ac_reg'].str.contains("B-HW"),'ac_type'] = 'A330'
new_df
# Out:
#             date  flight_num city_pair origin destination ac_reg block_time  \
# 0      12/9/2012         297   HKG HAN    HKG         HAN  B-HTF       1:54
# 1      12/9/2012         296   HAN HKG    HAN         HKG  B-HTF       1:58
# 2      13/9/2012         212   HKG HKT    HKG         HKT  B-HSM       3:17
# 3      13/9/2012         213   HKT HKG    HKT         HKG  B-HSM       3:36
# 4      3/10/2012         636   HKG HGH    HKG         HGH  B-HSK       2:04
# ...          ...         ...       ...    ...         ...    ...        ...
# 1953   26/9/2020         887   CTU HKG    CTU         HKG  B-HLT       2:40
# 1954  15/10/2020         725   HKG KUL    HKG         KUL  B-LBE       3:49
# 1955  15/10/2020         734   KUL HKG    KUL         HKG  B-LBE       3:45
# 1956  20/10/2020         299   HKG HAN    HKG         HAN  B-LAA       1:52
# 1957  20/10/2020         294   HAN HKG    HAN         HKG  B-LAA       1:49
#
#      off_block airborne  landing  landing on_block  takeoff  landing  landing  \
# 0         0:36     0:53     2:25        0     2:30        0     2:25        0
# 1         3:35     3:50     5:27        0     5:33        0     5:27        0
# 2         1:10     1:26     4:24        0     4:27        0     4:24        0
# 3         5:21     5:32     8:51        0     8:57        0     8:51        0
# 4         8:02     8:16    10:01        0    10:06        0    10:01        0
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 1953      5:43     6:14     8:16        0     8:23        0     8:16        0
# 1954      5:01     5:13     8:44        0     8:50        0     8:44        0
# 1955      9:46     9:58    13:26        1    13:31        1    13:26        1
# 1956      9:22     9:35    11:06        1    11:14        1    11:06        1
# 1957     12:05    12:26    13:47        0    13:54        0    13:47        0
#
#      autoland       commander ac_type
# 0           N    NETTLETON AD    A321
# 1           N    NETTLETON AD    A321
# 2           N    NETTLETON AD    A320
# 3           N    NETTLETON AD    A320
# 4           N       GUNTON MS    A320
# ...       ...             ...     ...
# 1953        N     O'CONNOR TE    A330
# 1954        N  NADENBOUSCH WJ    A330
# 1955        N  NADENBOUSCH WJ    A330
# 1956        N       JORDAN CR    A330
# 1957        N       JORDAN CR    A330
#
# [1958 rows x 18 columns]

# %%
new_df['ac_type'].value_counts()
# Out:
# A330      934
# A320      686
# A321      285
# airbus     53
# Name: ac_type, dtype: int64

# %%
#find which row has column ac_type with value airbus

df = new_df

#find which row has column ac_type with value airbus
df.loc[df['ac_type'] == "airbus"]
# Out:
#             date  flight_num city_pair origin destination ac_reg block_time  \
# 1013   11/9/2016         378   HKG OKA    HKG         OKA  B-HWM       2:40
# 1014   11/9/2016         379   OKA HKG    OKA         HKG  B-HWM       2:24
# 1015   11/9/2016         622   HKG HGH    HKG         HGH  B-HWM       2:02
# 1026   24/9/2016         153   BLR HKG    BLR         HKG  B-HWM       5:39
# 1029   29/9/2016         820   HKG CTU    HKG         CTU  B-HWM       2:20
# 1030   29/9/2016         821   CTU HKG    CTU         HKG  B-HWM       2:35
# 1090  30/12/2016         206   HKG PNH    HKG         PNH  B-HWM       2:43
# 1091  30/12/2016         209   PNH HKG    PNH         HKG  B-HWM       2:16
# 1099   23/1/2017         871   PVG HKG    PVG         HKG  B-HWM       2:54
# 1105   30/1/2017         820   HKG CTU    HKG         CTU  B-HWM       2:44
# 1106   30/1/2017         821   CTU HKG    CTU         HKG  B-HWM       2:34
# 1119   10/2/2017         691   HKG PEN    HKG         PEN  B-HWM       3:40
# 1120   10/2/2017         692   PEN HKG    PEN         HKG  B-HWM       3:53
# 1128   15/2/2017         831   PVG HKG    PVG         HKG  B-HWM       2:34
# 1206   21/5/2017         691   HKG PEN    HKG         PEN  B-HWM       3:42
# 1207   21/5/2017         692   PEN HKG    PEN         HKG  B-HWM       3:48
# 1225   10/6/2017         810   HKG NKG    HKG         NKG  B-HWM       2:38
# 1226   10/6/2017         811   NKG HKG    NKG         HKG  B-HWM       2:26
# 1254   11/7/2017         437   KHH HKG    KHH         HKG  B-HWM       1:27
# 1268   22/7/2017         858   HKG SHA    HKG         SHA  B-HWM       2:24
# 1269   22/7/2017         813   SHA HKG    SHA         HKG  B-HWM       2:39
# 1286   15/8/2017         804   HKG PVG    HKG         PVG  B-HWM       2:37
# 1287   15/8/2017         805   PVG HKG    PVG         HKG  B-HWM       2:27
# 1407   13/2/2018         831   PVG HKG    PVG         HKG  B-HWM       3:11
# 1466   11/5/2018         432   HKG KHH    HKG         KHH  B-HWM       1:25
# 1467   11/5/2018         433   KHH HKG    KHH         HKG  B-HWM       1:28
# 1474   16/5/2018         886   HKG CTU    HKG         CTU  B-HWM       2:36
# 1475   16/5/2018         887   CTU HKG    CTU         HKG  B-HWM       2:33
# 1480   27/5/2018         626   HKG HGH    HKG         HGH  B-HWM       2:17
# 1481   28/5/2018         627   HGH HKG    HGH         HKG  B-HWM       2:15
# 1493   28/6/2018         863   NKG HKG    NKG         HKG  B-HWM       2:39
# 1496   30/6/2018         886   HKG CTU    HKG         CTU  B-HWM       2:35
# 1497   30/6/2018         887   CTU HKG    CTU         HKG  B-HWM       2:30
# 1507   13/7/2018         623   HGH HKG    HGH         HKG  B-HWM       2:19
# 1526    2/8/2018         862   HKG NKG    HKG         NKG  B-HWM       2:32
# 1594  31/10/2018         782   HKG CAN    HKG         CAN  B-HWM       1:25
# 1595  31/10/2018         781   CAN HKG    CAN         HKG  B-HWM       1:07
# 1598   3/11/2018         782   HKG CAN    HKG         CAN  B-HWM       0:57
# 1599   3/11/2018         781   CAN HKG    CAN         HKG  B-HWM       1:10
# 1659   17/1/2019         438   HKG KHH    HKG         KHH  B-HWM       1:33
# 1666   24/1/2019         857   PVG HKG    PVG         HKG  B-HWM       2:41
# 1701   12/3/2019         486   HKG TPE    HKG         TPE  B-HWM       1:32
# 1702   12/3/2019         487   TPE HKG    TPE         HKG  B-HWM       1:51
# 1734   13/4/2019         623   HGH HKG    HGH         HKG  B-HWM       2:21
# 1751   15/5/2019         946   HKG XIY    HKG         XIY  B-HWM       2:45
# 1752   15/5/2019         943   XIY HKG    XIY         HKG  B-HWM       3:17
# 1753   16/5/2019         894   HKG PVG    HKG         PVG  B-HWM       2:41
# 1778   11/6/2019         730   KUL HKG    KUL         HKG  B-HWM       4:04
# 1779   11/6/2019         691   HKG PEN    HKG         PEN  B-HWM       3:42
# 1780   11/6/2019         692   PEN HKG    PEN         HKG  B-HWM       3:43
# 1835   18/8/2019         730   KUL HKG    KUL         HKG  B-HWM       4:15
# 1881  16/11/2019         950   HKG TAO    HKG         TAO  B-HWM       3:06
# 1882  16/11/2019         951   TAO HKG    TAO         HKG  B-HWM       3:07
#
#      off_block airborne  landing  landing on_block  takeoff  landing  landing  \
# 1013      4:24     4:52     6:57        1     7:04        1     6:57        1
# 1014      7:59     8:10    10:14        0    10:23        0    10:14        0
# 1015     11:53    12:08    13:47        1    13:55        1    13:47        1
# 1026     20:51    21:04  02:22+1        1  02:30+1        1  02:22+1        1
# 1029      2:07     2:25     4:26        0     4:27        0     4:26        0
# 1030      5:54     6:09     8:14        1     8:29        1     8:14        1
# 1090      9:22     9:37    11:57        0    12:05        0    11:57        0
# 1091     13:18    13:30    15:31        1    15:34        1    15:31        1
# 1099      0:34     0:57     3:21        0     3:28        0     3:21        0
# 1105      2:22     2:46     4:52        0     5:06        0     4:52        0
# 1106      5:58     6:15     8:22        0     8:32        0     8:22        0
# 1119      7:45     8:03    11:19        1    11:25        1    11:19        1
# 1120     23:56  00:17+1  03:46+1        0  03:49+1        0  03:46+1        0
# 1128      1:32     1:49     4:03        0     4:06        0     4:03        0
# 1206      7:52     8:11    11:26        1    11:34        1    11:26        1
# 1207     23:57  00:13+1  03:40+1        1  03:45+1        1  03:40+1        1
# 1225      2:49     3:02     5:22        0     5:27        1     5:22        0
# 1226     11:29    11:49    13:42        0    13:55        0    13:42        0
# 1254      7:02     7:13     8:20        1     8:29        1     8:20        1
# 1268      2:03     2:27     4:22        1     4:27        1     4:22        1
# 1269      5:44     6:02     8:18        0     8:23        0     8:18        0
# 1286      3:16     3:36     5:31        0     5:53        0     5:31        0
# 1287      7:00     7:17     9:20        0     9:27        0     9:20        0
# 1407      0:44     1:03     3:47        0     3:55        0     3:47        0
# 1466      0:44     1:02     2:03        0     2:09        0     2:03        0
# 1467      3:08     3:17     4:31        1     4:36        1     4:31        1
# 1474      2:36     2:55     4:58        1     5:12        1     4:58        1
# 1475      6:05     6:22     8:31        0     8:38        0     8:31        0
# 1480     23:42    23:56  01:56+1        1  01:59+1        1  01:56+1        1
# 1481      2:52     3:13     5:03        0     5:07        0     5:03        0
# 1493      0:20     0:40     2:52        0     2:59        0     2:52        0
# 1496      2:15     2:33     4:35        0     4:50        0     4:35        0
# 1497      5:56     6:09     8:20        1     8:26        1     8:20        1
# 1507     23:51  00:06+1  02:01+1        0  02:10+1        0  02:01+1        0
# 1526     11:01    11:14    13:27        0    13:33        0    13:27        0
# 1594      0:32     1:05     1:45        1     1:57        1     1:45        1
# 1595      3:12     3:35     4:15        0     4:19        0     4:15        0
# 1598      0:33     0:51     1:22        0     1:30        0     1:22        0
# 1599      2:30     2:56     3:36        1     3:40        1     3:36        1
# 1659     13:13    13:38    14:39        1    14:46        1    14:39        1
# 1666     23:18    23:33  01:51+1        0  01:59+1        0  01:51+1        0
# 1701      0:02     0:21     1:29        0     1:34        0     1:29        0
# 1702      2:39     2:53     4:22        1     4:30        1     4:22        1
# 1734     23:49  00:05+1  02:04+1        0  02:10+1        0  02:04+1        0
# 1751      3:29     3:47     6:05        1     6:14        1     6:05        1
# 1752      7:41     8:04    10:53        0    10:58        0    10:53        0
# 1753     11:17    11:32    13:36        1    13:58        1    13:36        1
# 1778      0:54     1:09     4:51        0     4:58        0     4:51        0
# 1779      7:19     7:41    10:55        0    11:01        0    10:55        0
# 1780     23:31    23:40  03:05+1        1  03:14+1        1  03:05+1        1
# 1835      1:32     1:56     5:41        1     5:47        1     5:41        1
# 1881      2:04     2:22     5:05        0     5:10        0     5:05        0
# 1882      6:32     6:48     9:33        1     9:39        1     9:33        1
#
#      autoland       commander ac_type
# 1013        N      PSAILA JAJ  airbus
# 1014        N      PSAILA JAJ  airbus
# 1015        N      PSAILA JAJ  airbus
# 1026        N      QUILKEY SR  airbus
# 1029        N      BURNARD SJ  airbus
# 1030        N      BURNARD SJ  airbus
# 1090        N    MCGREGOR MRD  airbus
# 1091        N    MCGREGOR MRD  airbus
# 1099        N       FRANCK MG  airbus
# 1105        N      PONTIKIS C  airbus
# 1106        N      PONTIKIS C  airbus
# 1119        N       ADCOCK IR  airbus
# 1120        N       ADCOCK IR  airbus
# 1128        N    TJERNBERG PJ  airbus
# 1206        N       ADCOCK IR  airbus
# 1207        N       ADCOCK IR  airbus
# 1225        N       WILLIS TJ  airbus
# 1226        N       WILLIS TJ  airbus
# 1254        N      WALTERS RV  airbus
# 1268        N       WILLIS TJ  airbus
# 1269        N       WILLIS TJ  airbus
# 1286        N  SCICLUNA JU...  airbus
# 1287        N  SCICLUNA JU...  airbus
# 1407        N     CHU YS IVAN  airbus
# 1466        N  HOFMAN-BANG AK  airbus
# 1467        N  HOFMAN-BANG AK  airbus
# 1474        N    PETTIGREW JB  airbus
# 1475        N    PETTIGREW JB  airbus
# 1480        N      WILSON GPM  airbus
# 1481        N      WILSON GPM  airbus
# 1493        N  FUKAZAWA NO...  airbus
# 1496        N      BOWKER MDW  airbus
# 1497        N      BOWKER MDW  airbus
# 1507        N        LAMPE WI  airbus
# 1526        N       GRAHAM NJ  airbus
# 1594        N    FAIRBAIRN JR  airbus
# 1595        N    FAIRBAIRN JR  airbus
# 1598        N    MACKINNON IC  airbus
# 1599        N    MACKINNON IC  airbus
# 1659        N       DOBBIN PF  airbus
# 1666        N       RAMAGE KJ  airbus
# 1701        N    EDWARDS JOHN  airbus
# 1702        N    EDWARDS JOHN  airbus
# 1734        N       BLOCH-J P  airbus
# 1751        N      TSOUSIS AD  airbus
# 1752        N      TSOUSIS AD  airbus
# 1753        N      TSOUSIS AD  airbus
# 1778        N   MACINTOSH ASP  airbus
# 1779        N   MACINTOSH ASP  airbus
# 1780        N   MACINTOSH ASP  airbus
# 1835        N   LO WT CLAYTON  airbus
# 1881        N    STUMP JULIEN  airbus
# 1882        N    STUMP JULIEN  airbus

# %%
#it was the HW series
df.loc[new_df['ac_reg'].str.contains("B-HW"),'ac_type'] = 'A330'

df
# Out:
#             date  flight_num city_pair origin destination ac_reg block_time  \
# 0      12/9/2012         297   HKG HAN    HKG         HAN  B-HTF       1:54
# 1      12/9/2012         296   HAN HKG    HAN         HKG  B-HTF       1:58
# 2      13/9/2012         212   HKG HKT    HKG         HKT  B-HSM       3:17
# 3      13/9/2012         213   HKT HKG    HKT         HKG  B-HSM       3:36
# 4      3/10/2012         636   HKG HGH    HKG         HGH  B-HSK       2:04
# ...          ...         ...       ...    ...         ...    ...        ...
# 1953   26/9/2020         887   CTU HKG    CTU         HKG  B-HLT       2:40
# 1954  15/10/2020         725   HKG KUL    HKG         KUL  B-LBE       3:49
# 1955  15/10/2020         734   KUL HKG    KUL         HKG  B-LBE       3:45
# 1956  20/10/2020         299   HKG HAN    HKG         HAN  B-LAA       1:52
# 1957  20/10/2020         294   HAN HKG    HAN         HKG  B-LAA       1:49
#
#      off_block airborne  landing  landing on_block  takeoff  landing  landing  \
# 0         0:36     0:53     2:25        0     2:30        0     2:25        0
# 1         3:35     3:50     5:27        0     5:33        0     5:27        0
# 2         1:10     1:26     4:24        0     4:27        0     4:24        0
# 3         5:21     5:32     8:51        0     8:57        0     8:51        0
# 4         8:02     8:16    10:01        0    10:06        0    10:01        0
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 1953      5:43     6:14     8:16        0     8:23        0     8:16        0
# 1954      5:01     5:13     8:44        0     8:50        0     8:44        0
# 1955      9:46     9:58    13:26        1    13:31        1    13:26        1
# 1956      9:22     9:35    11:06        1    11:14        1    11:06        1
# 1957     12:05    12:26    13:47        0    13:54        0    13:47        0
#
#      autoland       commander ac_type
# 0           N    NETTLETON AD    A321
# 1           N    NETTLETON AD    A321
# 2           N    NETTLETON AD    A320
# 3           N    NETTLETON AD    A320
# 4           N       GUNTON MS    A320
# ...       ...             ...     ...
# 1953        N     O'CONNOR TE    A330
# 1954        N  NADENBOUSCH WJ    A330
# 1955        N  NADENBOUSCH WJ    A330
# 1956        N       JORDAN CR    A330
# 1957        N       JORDAN CR    A330
#
# [1958 rows x 18 columns]

# %%
# new_df['ac_type'].value_counts().plot(kind='bar');


ax = new_df['ac_type'].value_counts().plot(kind='barh', figsize=(10,7), fontsize=13, color = colors["A320"]);
ax.set_alpha(0.8)
ax.set_title("Which aircraft type did I fly most?", fontsize=18)
ax.set_xlabel("Number of Sectors", fontsize=18);
ax.set_xticks(range(0,1100,100))

totals = []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)

for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_width()+.5, i.get_y()+.3, \
            str(round((i.get_width()/total)*100, 1))+'%', 
            fontsize=15,color='dimgrey')
    
ax.invert_yaxis()

ax;

plt.savefig('Which aircraft type did I fly most.png', bbox_inches='tight')

# %%
#Which captain did I fly with most?

df["commander"].value_counts().head(20).plot(kind="barh",figsize=(10,7),color = colors["A320"]).invert_yaxis()
plt.title("Which captain did I fly with most by Sectors?")
plt.xlabel("Sectors")
plt.savefig('Which captain did I fly with most by sectors.png',bbox_inches='tight')

# %%
df["commander"].value_counts()
# Out:
# MCCARTHY BRE       36
# O'CONNOR TE        34
# FARR SEAN JARON    30
# RAMAGE KJ          28
# LEUNG YH MARVIN    28
#                    ..
# HUML TOMAS          2
# CHENG WAI HO        2
# AAKERBERG TK        2
# LEAH MARK JASON     2
# BAUMGARTNER CR      2
# Name: commander, Length: 228, dtype: int64

# %%
df['block_time'] = pd.to_datetime(df['block_time'])
df['block_time'] = df['block_time'].dt.strftime('%H:%M:%S')
df['block_time'] = pd.to_timedelta(df['block_time'])

# %%
timespent = df.groupby('commander')['block_time'].sum()

timespent = df.groupby('commander')['block_time'].sum()
timespent = timespent.reset_index().set_index('commander')
plt.figure(num=None, figsize=(18, 10), dpi=80, facecolor='w')

timespent.block_time.astype('timedelta64[h]').sort_values(ascending=True)[-30:].plot.barh(color = colors["A320"])
plt.title("Cockpit Hours Shared, Top 30 Commanders")
plt.ylabel("Hours")
plt.xlabel("Commander")
plt.savefig('Cockpit Hours Shared Top 30 Commanders.png', bbox_inches='tight')

# %%
#Total Hours in an Airbus

x = df["block_time"].sum()

def convert_timedelta(duration):
    days, seconds = duration.days, duration.seconds
    hours = days * 24 + seconds // 3600
    minutes = (seconds % 3600) // 60
    seconds = (seconds % 60)
    print('{} hours, {} minutes'.format(hours, minutes))
    return hours, minutes, seconds
    

convert_timedelta(x)
# Out:
# 4933 hours, 26 minutes
# (4933, 26, 0)

# %%
total_hours = df['block_time'].sum()
total_hours
# Out:
# Timedelta('205 days 13:26:00')

# %%
import matplotlib.patches as mpatches

plt.figure(num=None, figsize=(18, 10), dpi=80, facecolor='w')
colors = {"A330": "#7D94CA", "A321": '#3F569D', "A320": '#1E3174'}
sort_graph = df.groupby(["ac_type","ac_reg"]).count()
sort_graph = sort_graph.sort_values(by=["ac_type","date"],ascending=False).date
# sort_graph.plot.bar(color= [colors[i] for i in sort_graph.index.get_level_values(0)],legend=False)
sort_graph.plot.bar(color=[colors[i] for i in sort_graph.index.get_level_values(0)])
plt.title("Sectors On Each Airframe Sorted by Type and Registration")
plt.ylabel("Count")
plt.xlabel("Type and Registration")
plt.xticks(np.arange(sort_graph.shape[0], step=1), [i for i in sort_graph.index.get_level_values(1)])

a330_patch = mpatches.Patch(color="#7D94CA", label='A330')
a321_patch = mpatches.Patch(color="#3F569D", label='A321')
a320_patch = mpatches.Patch(color="#1E3174", label='A320')
plt.legend(handles=[a330_patch,a321_patch,a320_patch],loc="best")
plt.savefig('Sectors By Airframe.png', bbox_inches='tight')

# %%
china_l = ['HKG','HGH','SYX','NGB','PVG','CSX','HAK','NKG','CGO','WNZ','XMN','FOC','CKG','CAN','XIY','WUH','CTU','PEK','TAO','KWL','KMG','SHA','TNA',"NNG","KMQ"]
non_china_l = ['HKT','HAN','CRK','OKA','BKI','TPE', 'PNH','RMQ','KHH','FUK','CJU','CNX','RGN','DAD','MNL','CCU','REP','PUS','HND','HIJ','BLR','PEN','KIJ','DPS','KUL','DAC','KTM',"DVO","TKS"]
china_colors = {k:"#df2407" for k in china_l}
non_china_colors = {k:"#22559E" for k in non_china_l}

def merge_two_dicts(x, y):
    z = x.copy()   # start with x's keys and values
    z.update(y)    # modifies z with y's keys and values & returns None
    return z

port_colors =  merge_two_dicts(china_colors, non_china_colors)


plt.figure(num=None, figsize=(18, 10), dpi=80, facecolor='w')
dest_graph = df.destination.value_counts()[1:]
dest_graph.plot.bar(color=["black" if i not in port_colors else port_colors[i] for i in dest_graph.index])
plt.title("Sectors To Each Destination (Not-HKG)")
plt.ylabel("Count")
plt.xlabel("Destinations")


china_patch = mpatches.Patch(color="#df2407", label='China')
non_china_patch = mpatches.Patch(color="#22559E", label='Non-China')

plt.legend(handles=[china_patch,non_china_patch],loc="best")
plt.savefig('Destinations Count Not Hong Kong.png', bbox_inches='tight')

# %%
df_icao = pd.read_csv("https://raw.githubusercontent.com/jpatokal/openflights/master/data/airports.dat", header=None, index_col=0)

# %%
df_icao.columns = ['airport_name','city_name','country','IATA','ICAO','latitude','longtitude','a','b','c','region','d','e']

# %%
df_icao.shape
# Out:
# (7698, 13)

# %%
ka_icao = pd.DataFrame(columns=['airport_name','city_name','country','IATA','ICAO','latitude','longtitude','a','b','c','region','d','e'])

for i in list(port_colors.keys()):
    df2 = df_icao[df_icao["IATA"]==i]
    ka_icao = ka_icao.append(df2)

# %%
ka_icao.head()
# Out:
#         airport_name  city_name    country IATA  ICAO   latitude  longtitude  \
# 3077  Hong Kong I...  Hong Kong  Hong Kong  HKG  VHHH  22.308901  113.915001
# 3386  Hangzhou Xi...   Hangzhou      China  HGH  ZSHC  30.229500  120.433998
# 4030  Sanya Phoen...      Sanya      China  SYX  ZJSY  18.302900  109.412003
# 3387  Ningbo Lish...      Ninbo      China  NGB  ZSNB  29.826700  121.461998
# 3406  Shanghai Pu...   Shanghai      China  PVG  ZSPD  31.143400  121.805000
#
#        a  b  c          region        d            e
# 3077  28  8  U  Asia/Hong_Kong  airport  OurAirports
# 3386  23  8  U   Asia/Shanghai  airport  OurAirports
# 4030  92  8  U   Asia/Shanghai  airport  OurAirports
# 3387  13  8  U   Asia/Shanghai  airport  OurAirports
# 3406  13  8  U   Asia/Shanghai  airport  OurAirports

# %%
temp_df = ka_icao[["IATA","latitude","longtitude"]]
temp_list = temp_df.values.tolist()
distance_d = {}
for value in temp_list:
    distance_d[value[0]] = (value[1],value[2]) 
distance_d
# Out:
# {'HKG': (22.308901000000002, 113.915001),
#  'HGH': (30.22949981689453, 120.43399810791016),
#  'SYX': (18.30290031433105, 109.41200256347656),
#  'NGB': (29.82670021057129, 121.46199798583984),
#  'PVG': (31.143400192260746, 121.80500030517578),
#  'CSX': (28.189199447600004, 113.220001221),
#  'HAK': (19.93490028381348, 110.45899963378906),
#  'NKG': (31.742000579833984, 118.86199951171876),
#  'CGO': (34.519699096699995, 113.84100341799999),
#  'WNZ': (27.912201, 120.851997),
#  'XMN': (24.54400062561035, 118.12799835205078),
#  'FOC': (25.935100555419922, 119.66300201416016),
#  'CKG': (29.719200134277344, 106.64199829101562),
#  'CAN': (23.39240074157715, 113.29900360107422),
#  'XIY': (34.447102, 108.751999),
#  'WUH': (30.7838, 114.208),
#  'CTU': (30.578500747680664, 103.9469985961914),
#  'PEK': (40.0801010131836, 116.58499908447266),
#  'TAO': (36.2661018372, 120.374000549),
#  'KWL': (25.21809959411621, 110.03900146484376),
#  'KMG': (25.101944399999997, 102.9291667),
#  'SHA': (31.19790077209473, 121.33599853515624),
#  'TNA': (36.857200622558594, 117.21600341796876),
#  'NNG': (22.60829925537109, 108.1719970703125),
#  'KMQ': (36.39459991455078, 136.40699768066406),
#  'HKT': (8.1132, 98.316902),
#  'HAN': (21.221200942993164, 105.80699920654295),
#  'CRK': (15.186, 120.559998),
#  'OKA': (26.1958007812, 127.64600372299999),
#  'BKI': (5.9372100830078125, 116.0510025024414),
#  'TPE': (25.0777, 121.233002),
#  'PNH': (11.546600341796875, 104.84400177001952),
#  'RMQ': (24.26469993591309, 120.62100219726562),
#  'KHH': (22.57710075378418, 120.3499984741211),
#  'FUK': (33.585899353027344, 130.45100402832028),
#  'CJU': (33.51129913330078, 126.49299621582031),
#  'CNX': (18.7667999268, 98.962600708),
#  'RGN': (16.907300949099998, 96.1332015991),
#  'DAD': (16.043899536132812, 108.1989974975586),
#  'MNL': (14.5086, 121.019997),
#  'CCU': (22.654699325561523, 88.44670104980469),
#  'REP': (13.410699844400003, 103.81300354),
#  'PUS': (35.1795005798, 128.93800354),
#  'HND': (35.552299, 139.779999),
#  'HIJ': (34.4361000061, 132.91900634799998),
#  'BLR': (13.1979, 77.706299),
#  'PEN': (5.297140121459961, 100.2770004272461),
#  'KIJ': (37.955898284899995, 139.121002197),
#  'DPS': (-8.7481698989868, 115.16699981689),
#  'KUL': (2.7455799579619997, 101.70999908446998),
#  'DAC': (23.843347, 90.39778299999999),
#  'KTM': (27.6966, 85.3591),
#  'DVO': (7.1255202293396, 125.64600372314452),
#  'TKS': (34.132801, 134.60699499999998)}

# %%
from geopy import distance

#sample

newport_ri = (41.49008, -71.312796)
cleveland_oh = (41.499498, -81.695391)
print(distance.distance(newport_ri, cleveland_oh).nm)

wellington = (-41.32, 174.81)
salamanca = (40.96, -5.50)
print(distance.distance(wellington, salamanca).nm)
# Out:
# 467.84850589085784
# 10777.364615201843

# %%
def applydistance(origin,destination):
    origin = distance_d[origin]
    destination = distance_d[destination]
    return distance.distance(origin,destination).nm

# %%
applydistance(df.origin.values[0],df.destination.values[0])
# Out:
# 457.40397603886714

# %%
df["distanceflown"] = np.arange(df.shape[0])
df.distanceflown = df.distanceflown.apply(lambda x: round(applydistance(df.origin.values[x],df.destination.values[x])),0)

###df.distanceflown = df.distanceflown.apply(applydistance(df.origin,df.destination))

# %%
df.distanceflown.sum()
# Out:
# 1393061

# %%
import matplotlib.ticker as mtick

plt.figure(num=None, figsize=(18, 10), dpi=80, facecolor='w')
total_distance_flown = df.distanceflown.sum()
distance_to_moon = 207560.475

quick_d = {"Total Distance Flown": total_distance_flown,"Distance to the Moon":distance_to_moon}
plt.bar(quick_d.keys(), quick_d.values(), color=colors['A320'])
plt.title("Total Distance Flown versus Distance to the Moon")
plt.yticks(np.arange(0, 1600000, step=100000))
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f'))
plt.ylabel("Nautical Miles")
plt.savefig('Total Distance Flown versus Distance to the Moon.png', bbox_inches='tight')

# %%
###df.distanceflown = df.distanceflown.apply(applydistance(df.origin,df.destination))

# %%
df.commander.value_counts()
# Out:
# MCCARTHY BRE       36
# O'CONNOR TE        34
# FARR SEAN JARON    30
# RAMAGE KJ          28
# LEUNG YH MARVIN    28
#                    ..
# HUML TOMAS          2
# CHENG WAI HO        2
# AAKERBERG TK        2
# LEAH MARK JASON     2
# BAUMGARTNER CR      2
# Name: commander, Length: 228, dtype: int64
